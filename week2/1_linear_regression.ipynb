# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import numpy as np

torch.manual_seed(1)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 토이 데이터 생성

# %%
x = torch.arange(1,101)
x = Variable(x).unsqueeze(1) # view(1,-1)

y = torch.linspace(0,10,100) + torch.randn(100)
y = Variable(y).unsqueeze(1) # view(1,-1)

# %%
plt.plot(x.data.numpy(), y.data.numpy(), 'ro', label='train data')
# plt.plot(x_train, predicted, label='Fitted line')
plt.legend()
plt.show()

# %% [markdown]
# ### 모델링

# %%
model = nn.Linear(1,1)
print([p for p in model.parameters()])

loss_function = nn.MSELoss()
# Out:
# [Parameter containing:
# -0.5580
# [torch.FloatTensor of size 1x1]
# , Parameter containing:
#  0.1760
# [torch.FloatTensor of size 1]
# ]

# %% [markdown]
# ### 트레이닝

# %%
STEP=6
learning_rate=0.0001

# %%
for step in range(STEP):
    model.zero_grad()
    pred = model(x)
    loss = loss_function(pred,y)
    
    print("[%d/%d] loss : %.3f" % (step,STEP,loss.data[0]))
    plt.plot(x.data.numpy(), y.data.numpy(), 'ro', label='train data')
    plt.plot(x.data.numpy(), pred.data.numpy(), label='step'+str(step))
    plt.legend()
    plt.show()
    
    # gradient descent
    loss.backward()
    for param in model.parameters():
        param.data.add_(-learning_rate, param.grad.data)
# Out:
# [0/6] loss : 1442.141
# [1/6] loss : 151.543
# [2/6] loss : 16.772
# [3/6] loss : 2.698
# [4/6] loss : 1.229
# [5/6] loss : 1.075

# %% [markdown]
# ### TODO list

# %% [markdown]
# * 모델을 클래스 형태로 바꿔보기 (nn.Module 상속)
# * 변수를 더 늘려보기 (univariate -> multivariate)
# * learning rate 바꿔보기 (늘리거나 줄여서 결과 확인해보기)
